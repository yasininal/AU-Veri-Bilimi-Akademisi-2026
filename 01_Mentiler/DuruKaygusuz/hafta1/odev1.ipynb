# %% [markdown]
# ##VERIABLES

# %%
x = 5

# %%
type(x)
# Out:
# int

# %%
y = 3.4

# %%
type(y)
# Out:
# float

# %%
z = "Hello World"

# %%
type(z)
# Out:
# str

# %%
print(x * y + len(z))
# Out:
# 28.0

# %% [markdown]
# ##SLICING

# %%
karisikString = "Veri Bilimi Topluluğu 2026"

# %%
print(karisikString[2:])
# Out:
# ri Bilimi Topluluğu 2026

# %%
print(karisikString[-4:])
# Out:
# 2026

# %%
print(karisikString[:-5])
# Out:
# Veri Bilimi Topluluğu

# %%
#step size

# %%
print(karisikString[::-1])
# Out:
# 6202 uğululpoT imiliB ireV

# %%
print(karisikString[2:12:3])
# Out:
# rBi

# %% [markdown]
# ##STRING METHODS

# %%
isim = "duru"

# %%
soyIsim = "kaygusuz"

# %%
bagırarakIsim = isim.upper()

# %%
print(bagırarakIsim)
# Out:
# DURU

# %%
tamIsım = isim.capitalize() + " " + soyIsim.capitalize()

# %%
print(tamIsım)
# Out:
# Duru Kaygusuz

# %% [markdown]
# ##LISTS

# %%
liste1 = [10 , 20 , 30 , 40]

# %%
print(liste1)
# Out:
# [10, 20, 30, 40]

# %%
liste1.append(50)

# %%
print(liste1)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(liste1[1])
# Out:
# 20

# %%
stringListe = ["Deniz" , "Nisa" , "Ilgın" , "Ravza"]

# %%
print(stringListe.pop())
# Out:
# Ravza

# %%
print(stringListe)
# Out:
# ['Deniz', 'Nisa', 'Ilgın']

# %%
stringListe.append("Itır")

# %%
print(stringListe)
# Out:
# ['Nisa', 'Ilgın', 'Itır']

# %%
stringListe.remove("Deniz")

# %%
print(stringListe.count("Itır")) #count o elemanın sayısını verir
# Out:
# 1

# %%
stringListe.reverse()

# %%
nestedList = [1,3.5,"veri",3,[6,"z"]]

# %%
zHarfi = nestedList[4][1]

# %%
print(zHarfi)
# Out:
# z

# %% [markdown]
# ##DICTIONARY

# %%
fiyatSozluk = {"etek" : 100 , "elbise" : 200 , "sapka" : 150}

# %%
print(fiyatSozluk.keys())
# Out:
# dict_keys(['etek', 'elbise', 'sapka'])

# %%
print(fiyatSozluk.values())
# Out:
# dict_values([100, 200, 150])

# %%
print(fiyatSozluk["elbise"])
# Out:
# 200

# %% [markdown]
# ##SET

# %%
newSet = {1,2,1,4}

# %%
type(newSet)
# Out:
# set

# %%
newSet
# Out:
# {1, 2, 4}

# %%
newSet.add(23)

# %%
newSet
# Out:
# {1, 2, 4, 23}

# %% [markdown]
# tuple, liste ile aynı, sadece elemanın değerini değiştiremiyoruz

# %% [markdown]
# ##BOOL AND COMPARISON

# %%
x = 3

# %%
y = 5

# %%
x <= y
# Out:
# True

# %%
x > y
# Out:
# False

# %%
x < 10 and y > 3
# Out:
# True

# %%
x < 10 or y == 2
# Out:
# True

# %%
not x == 5
# Out:
# True
